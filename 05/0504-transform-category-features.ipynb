# %%
import pandas as pd
df_sales = pd.read_csv('florist-order-record.csv')
df_sales.head()
# Out:
#     Order ProductID           Date                   Products  Number  Price  \
# 0  536374     21258  6/1/2020 9:09        Five Colorful Roses      32  10.95
# 1  536376     22114  6/1/2020 9:32           25 White Jasmine      48   3.45
# 2  536376     21733  6/1/2020 9:32  3 Sunflowers 5 Eucalyptus      64   2.55
# 3  536378     22386  6/1/2020 9:37                  Lily Pink      10   1.95
# 4  536378    85099C  6/1/2020 9:37        Champagne Carnation      10   1.95
#
#    UserID      City
# 0   15100   Beijing
# 1   15291  Shanghai
# 2   15291  Shanghai
# 3   14688   Beijing
# 4   14688   Beijing

# %%
category_features = ['City']
df_sales = pd.get_dummies(df_sales,
                          drop_first=True, 
                          columns=category_features) 
df_sales
# Out:
#         Order ProductID            Date                   Products  Number  \
# 0      536374     21258   6/1/2020 9:09        Five Colorful Roses      32
# 1      536376     22114   6/1/2020 9:32           25 White Jasmine      48
# 2      536376     21733   6/1/2020 9:32  3 Sunflowers 5 Eucalyptus      64
# 3      536378     22386   6/1/2020 9:37                  Lily Pink      10
# 4      536378    85099C   6/1/2020 9:37        Champagne Carnation      10
# ...       ...       ...             ...                        ...     ...
# 87175  581585     21684  6/9/2021 12:31   Product Description Mask      12
# 87176  581585     22398  6/9/2021 12:31   Product Description Mask      12
# 87177  581585     23328  6/9/2021 12:31   Product Description Mask       4
# 87178  581585     23145  6/9/2021 12:31   Product Description Mask      12
# 87179  581585     22466  6/9/2021 12:31   Product Description Mask      12
#
#         Price  UserID  City_Beijing  City_Chendu  City_Guangzhou  \
# ...
